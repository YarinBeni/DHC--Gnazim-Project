# %% [markdown]
# <a href="https://colab.research.google.com/github/YarinBeni/DHC--Gnazim-Project/blob/main/ArchaeologyLettersRecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Letter Recognition in Archaeology Writing using Deep Learning
#
# ## Project Overview
# This project aims to address the unique challenge of letter recognition in archaeological writings through the implementation of deep learning techniques. Our methodology is based on a self-supervised approach for multi-class classification.
#
# Our goal is to aid archaeologists and researchers in understanding ancient scripts more effectively, thereby unlocking the potential for significant historical insights.
#
# ## How to Run this Notebook
#
# 1. drag and drop a ziped folder named "Database - Copy.zip" of the data in this colab folders in path /content/HERE (located in https://drive.google.com/drive/folders/1RZWxjr8cXaWmjOspGbIPFmN1TVrVSIYX?usp=sharing_eip_m&ts=642c12f4).
#
# 2. wait for upload to be finished.
#
# 3. run the code cell by cell (Ignore the Cell with TEST in there title).
# **Note:** This notebook is set up to be run from top to bottom. Running cells out of order may result in errors.
#
# Enjoy exploring and don't hesitate to reach out if you have any questions or encounter any issues!

# %% [markdown]
# # Future Tasks:
# 1a) find relevant degradation for the model:
#   possible list of ideas:
#    invraint to: camera position,random cracks, old photo filter, random deletes(random crops),random lighting(normalization?) *--DONE*
#
# 1b) future test combination of best degradations as did in "Simclr" paper? *--DONE*
#
# 2) figure out how to train on gpu local or in googlecolab --DONE
#
# 3) understand how pytorch experiments and weights and baiss from FSDL Lab02 and lab04
#
# 4) start model training --DONE
#
# 5) make sure overfit on single batch --DONE
#
# 6) expand to 100 epochs and check results on maybe another models

# %% [markdown]
# #*Install Packages:*

# %%
# !pip install pytorch_lightning lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.0.2-py3-none-any.whl (719 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.0/719.0 kB 38.6 MB/s eta 0:00:00
# Collecting lightly
#   Downloading lightly-1.4.6-py3-none-any.whl (653 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.7/653.7 kB 63.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.22.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.0.1+cu118)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.4.0)
# Collecting torchmetrics>=0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 52.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.5.0)
# Collecting lightning-utilities>=0.7.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from lightly) (2022.12.7)
# Collecting hydra-core>=1.0.0 (from lightly)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 24.5 MB/s eta 0:00:00
# Collecting lightly-utils~=0.0.0 (from lightly)
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from lightly) (2.27.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from lightly) (1.16.0)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.10/dist-packages (from lightly) (1.26.15)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from lightly) (0.15.2+cu118)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 78.2 MB/s eta 0:00:00
# Collecting omegaconf<2.4,>=2.2 (from hydra-core>=1.0.0->lightly)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 12.4 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.0.0->lightly)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 19.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from lightly-utils~=0.0.0->lightly) (8.4.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->lightly) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->lightly) (3.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch_lightning) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch_lightning) (16.0.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.7 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.1 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 22.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->pytorch_lightning) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->pytorch_lightning) (1.3.0)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=bca5a8675b04bd9e82ff607a67aed30e9a77e7a79a9109f01080b33fc085139c
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, omegaconf, multidict, lightning-utilities, lightly-utils, frozenlist, async-timeout, yarl, hydra-core, aiosignal, aiohttp, torchmetrics, pytorch_lightning, lightly
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 frozenlist-1.3.3 hydra-core-1.3.2 lightly-1.4.6 lightly-utils-0.0.2 lightning-utilities-0.8.0 multidict-6.0.4 omegaconf-2.3.0 pytorch_lightning-2.0.2 torchmetrics-0.11.4 yarl-1.9.2

# %% [markdown]
# #*Drop Database ziped Folder into relvent Path By code in the cell and run cell:*

# %%
from zipfile import ZipFile
file_name = "/content/Database - Copy.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %% [markdown]
# #*Create Dataset with DataBaseFactory Class:*

# %%
import cv2
import json
import numpy as np
import os
import pandas as pd


class DatabaseFactory:
    def __init__(self, data_path):
        self.samples_data = {}
        self.original_images_data = {}
        self.samples_amount = 0

        for dirpath, dirnames, filesnames in os.walk(data_path):  # search in database folder
            if filesnames:  # means there is photos in the folder
                self.image_info = {}
                self.parser_image_file(filesnames)
                self.parse_json_file(dirpath, filesnames)
        self.save_samples_data_to_csv()

    def save_samples_data_to_csv(self):
        df1 = pd.DataFrame.from_dict(self.samples_data, orient='index')
        df1.to_csv('samples_database.csv')

        df2 = pd.DataFrame.from_dict(self.original_images_data, orient='index')
        df2.to_csv('original_images_database.csv')

    def parse_json_file(self, dirpath, filesnames):
        for filename in filesnames:
            if filename.endswith("json"):
                print(f"this is image number: {self.samples_amount}, file name: {filename}\n")
                self.image_info["original_folder_path"] = dirpath
                self.image_info["json_name"] = "/" + filename

                print("Path Name made by CODE: ",self.image_info["original_folder_path"] + self.image_info["json_name"])
                print("Path Name in FOLDER and Path Name made by CODE are the same: ",
                      self.image_info["original_folder_path"] + self.image_info["json_name"]==
                      "/content/Database - Copy/Arad (end of 7th century Judah)/Arad24_1972-121_I-86564_3200dpi_16b/testjson.json")
                
                with open(self.image_info["original_folder_path"] + self.image_info["json_name"], 'r') as f:
                    self.data = json.load(f)
                    f.close()
                for i in range((len(self.data['annotations'][0]['result']))):
                    self.parser_image_info(i)

                    cropped = self.get_polygon_crop()
                    if not os.path.exists(self.image_info["original_folder_path"] + "\\Samples"):
                        os.makedirs(self.image_info["original_folder_path"] + "\\Samples")

                    self.new_sample_info = {}
                    self.fill_new_sample_info()
                    if self.image_info:
                        self.samples_data[self.samples_amount] = self.new_sample_info
                        self.original_images_data[self.image_info["original_folder_path"]] = self.image_info
                    self.samples_amount += 1
                    cv2.imwrite(self.new_sample_info["sample_path"], cropped)

    def parser_image_file(self, filesnames):
        for filename in filesnames:
            if filename.endswith("png"):
                self.image_info["original_image_name"] = "/" + filename

    def fill_new_sample_info(self):
        self.new_sample_info["sample_name"] = str(self.samples_amount)
        self.new_sample_info["from_image"] = self.image_info["original_image_name"][1:]
        self.new_sample_info["from_area"] = self.image_info["original_folder_path"].rsplit("/", 3)[-2]
        self.new_sample_info["sample_path"] = self.image_info["original_folder_path"] + "/Samples/" \
                                              + self.new_sample_info["sample_name"] + '.png'
        self.new_sample_info["label"] = self.new_sample_info["from_area"] + "_-_" + self.new_sample_info[
            "from_image"]

    def parser_image_info(self, i):
        self.image_info['points'] = self.data['annotations'][0]['result'][i]['value']['points']
        self.image_info['width'] = self.data['annotations'][0]['result'][i]["original_width"]
        self.image_info['height'] = self.data['annotations'][0]['result'][i]["original_height"]
        self.image_info['scaled_points'] = np.array(
            [[int(x / 100.0 * self.image_info['width']), int(y / 100.0 * self.image_info['height'])]
             for x, y in self.image_info['points']], dtype=np.int32)

    def annotate_image(self):
        pass
        # scaled_points = self.get_scaled_points()
        # cv2.polylines(self.image, [scaled_points], True, (0, 255, 0), thickness=20)
        # cv2.imshow('image', self.image)
        # cv2.waitKey(0)
        # cv2.destroyAllWindows()

    def rectangle_crop_and_show(self):
        pass
        # x, y, w, h = cv2.boundingRect(np.array([self.scaled_points], dtype=np.int32))
        # cropped = self.image[y:y + h, x:x + w]
        # cv2.imshow('Cropped Image', cropped)
        # cv2.waitKey(0)
        # cv2.destroyAllWindows()

    def get_polygon_crop(self):
        #print("in get_polygon_crop: ",self.image_info["original_folder_path"] + self.image_info["original_image_name"])
        image = cv2.imread(self.image_info["original_folder_path"] + self.image_info["original_image_name"])
        x, y, w, h = cv2.boundingRect(np.array([self.image_info['scaled_points']], dtype=np.int32))
        mask = np.zeros((image.shape[0], image.shape[1]), dtype=np.uint8)
        cv2.fillPoly(mask, [self.image_info['scaled_points']], 255)
        masked_image = cv2.bitwise_and(image, image, mask=mask)
        cropped = masked_image[y:y + h, x:x + w]
        cropped[mask[y:y + h, x:x + w] == 0] = 255
        return cropped
DatabaseFactory(r"/content/Database - Copy")
# Out:
# this is image number: 0, file name: Samria_37_4551.json
#
# Path Name made by CODE:  /content/Database - Copy/Samaria (first half of 8th century Israel)/Samaria_37_4551_16b_4800dpi_3/Samria_37_4551.json
# Path Name in FOLDER and Path Name made by CODE are the same:  False
# this is image number: 14, file name: SAM_I_597.json
#
# Path Name made by CODE:  /content/Database - Copy/Samaria (first half of 8th century Israel)/SAM_I_597_ostr18_57_2_55_3931_4582_4583_4660_diapositive_1200ppi/SAM_I_597.json
# Path Name in FOLDER and Path Name made by CODE are the same:  False
# this is image number: 49, file name: Mezad_Hashavyahu.json
#
# Path Name made by CODE:  /content/Database - Copy/Mezad Hashaviyahu (7th century Judah)/Mezad_Hashavyahu.json
# Path Name in FOLDER and Path Name made by CODE are the same:  False
# this is image number: 124, file name: Jason_metadata_Arad02_1967.json
#
# Path Name made by CODE:  /content/Database - Copy/Arad (end of 7th century Judah)/Arad02_1967-625_I-86581_3200dpi_16b/Jason_metadata_Arad02_1967.json
# Path Name in FOLDER and Path Name made by CODE are the same:  False
# this is image number: 159, file name: testjson.json
#
# Path Name made by CODE:  /content/Database - Copy/Arad (end of 7th century Judah)/Arad24_1972-121_I-86564_3200dpi_16b/testjson.json
# Path Name in FOLDER and Path Name made by CODE are the same:  True
# this is image number: 249, file name: 9 json.json
#
# Path Name made by CODE:  /content/Database - Copy/Ajrud (first half of 8th century - Sinai desert)/9/9 json.json
# Path Name in FOLDER and Path Name made by CODE are the same:  False
# this is image number: 252, file name: 1951 5 json.json
#
# Path Name made by CODE:  /content/Database - Copy/Ajrud (first half of 8th century - Sinai desert)/1951 5/1951 5 json.json
# Path Name in FOLDER and Path Name made by CODE are the same:  False
# this is image number: 277, file name: 2 json.json
#
# Path Name made by CODE:  /content/Database - Copy/Ajrud (first half of 8th century - Sinai desert)/2/2 json.json
# Path Name in FOLDER and Path Name made by CODE are the same:  False
# this is image number: 296, file name: B-132624.json
#
# Path Name made by CODE:  /content/Database - Copy/Lachish (end of 7th century Judah)/B-132624-300617110711/B-132624.json
# Path Name in FOLDER and Path Name made by CODE are the same:  False
# this is image number: 365, file name: Lachish_1938 jason.json
#
# Path Name made by CODE:  /content/Database - Copy/Lachish (end of 7th century Judah)/Lachish_1938-128_M-19493a_3200dpi_16b/Lachish_1938 jason.json
# Path Name in FOLDER and Path Name made by CODE are the same:  False

# %% [markdown]
# #*Initialize CustomDataset Class:*#

# %%
import math
import os
import cv2
import numpy as np
from torch.utils.data import Dataset, DataLoader
import cv2
import torch
import pandas as pd
import torch.nn.functional as F

#######################################################
#                  Create Dataset
#######################################################
DIC_NAME = "dic_name"
FOLDER_PATH = "folder_path"
worms_params = {
    # "batch_size": 2,  # the number of image per sample check if need to be changed -A: FOR NOW ITS FINE !
    "num_workers": 4,
    "image_max_size": (0, 0),
    "in_channels": 1,  # to make sure because its gray image 1 channel or maybe 3 from tensor size? -A: YES
    "num_classes": None  # to make sure we dont have classes because our label is an image -A: EXACTLY !
}
#CSV_DATASET_PATH = r"C:\Users\yarin\PycharmProjects\GuidedProject\samples_database.csv"
CSV_DATASET_PATH ="/content/samples_database.csv"

class CustomDataset(Dataset):
    def __init__(self, image_paths, transform_dic={}):
        self.image_pad_param = self.get_max_image_size(image_paths.rsplit("\\", 1)[0] + "\\Database")
        self.image_paths = pd.read_csv(image_paths)
        self.transform_dic = transform_dic

    def __len__(self):
        return self.image_paths.shape[0]

    def __getitem__(self, index):
        metadata_sample = self.image_paths.loc[index]
        dic_image = torch.from_numpy(cv2.resize(cv2.imread(metadata_sample["sample_path"], 1), (384, 384))).permute(2,0,1).float()
        # dic_image = self.pad_sample(dic_image)

        # Add a resize operation to the transformation pipeline
        # dic_image = F.interpolate(dic_image, size=(3,384, 384))


        return dic_image[None,:,:], dict(metadata_sample)
        #return dic_image[None,:,:],dic_image[None,:,:]

    def pad_sample(self, dic):
        if self.image_pad_param[0] == 0 and self.image_pad_param[1] == 0:
            return dic
        new_image_height, new_image_width = self.image_pad_param
        old_image_height, old_image_width = dic.shape[0], dic.shape[1]
        w_pad = new_image_width - old_image_width
        h_pad = new_image_height - old_image_height

        if w_pad % 2 != 0:
            w1_pad = int(math.ceil(w_pad / 2)) - 1
            w2_pad = int(math.ceil(w_pad / 2))
        else:
            w1_pad = int(math.ceil(w_pad / 2))
            w2_pad = int(math.ceil(w_pad / 2))

        if h_pad % 2 != 0:
            h1_pad = int(math.ceil(h_pad / 2)) - 1
            h2_pad = int(math.ceil(h_pad / 2))
        else:
            h1_pad = int(math.ceil(h_pad / 2))
            h2_pad = int(math.ceil(h_pad / 2))

        pad_image = torch.nn.ConstantPad2d((w1_pad, w2_pad, h1_pad, h2_pad), 255)(dic.permute(2, 0, 1))
        pad_image = pad_image.permute(0, 1,2)

        return pad_image

    def get_max_image_size(self, data_path):
        max_h, max_w = 0, 0

        for dirpath, dirnames, filenames in os.walk(data_path):
            if filenames and dirpath.rsplit("\\", 1)[1] == 'Samples':
                for filename in filenames:
                    if filename.endswith('.png'):
                        filepath = os.path.join(dirpath, filename)
                        img = cv2.imread(filepath)
                        h, w = img.shape[:2]
                        if h > max_h:
                            max_h = h
                        if w > max_w:
                            max_w = w
        return max_h, max_w

# %% [markdown]
# #*Initialize Dino Model:*#

# %%
# Note: The model and training settings do not follow the reference settings
# from the paper. The settings are chosen such that the example can easily be
# run on a small dataset with a single GPU.

import copy

import pytorch_lightning as pl
import torch
import torchvision
from torch import nn

from lightly.data import LightlyDataset
from lightly.data.multi_view_collate import MultiViewCollate
from lightly.loss import DINOLoss
from lightly.models.modules import DINOProjectionHead
from lightly.models.utils import deactivate_requires_grad, update_momentum
from lightly.transforms.dino_transform import DINOTransform
from lightly.utils.scheduler import cosine_schedule


class DINO(pl.LightningModule):
    def __init__(self,lr=0.001):
        super().__init__()
        #resnet = torchvision.models.resnet18()
        # backbone = nn.Sequential(*list(resnet.children())[:-1])
        # input_dim = 512
        # instead of a resnet you can also use a vision transformer backbone as in the
        # original paper (you might have to reduce the batch size in this case):
        backbone = torch.hub.load('facebookresearch/dino:main', 'dino_vits16', pretrained=True)
        input_dim = backbone.embed_dim
        self.lr=lr
        self.printed_epoch = -1
        self.student_backbone = backbone
        self.student_head = DINOProjectionHead(
            input_dim, 512, 64, 2048, freeze_last_layer=1
        )
        self.teacher_backbone = copy.deepcopy(backbone)
        self.teacher_head = DINOProjectionHead(input_dim, 512, 64, 2048)
        deactivate_requires_grad(self.teacher_backbone)
        deactivate_requires_grad(self.teacher_head)

        self.criterion = DINOLoss(output_dim=2048, warmup_teacher_temp_epochs=5)

    def forward(self, x):
        y = self.student_backbone(x).flatten(start_dim=1)
        z = self.student_head(y)
        return z

    def forward_teacher(self, x):
        y = self.teacher_backbone(x).flatten(start_dim=1)
        z = self.teacher_head(y)
        return z

    def training_step(self, batch, batch_idx):
        momentum = cosine_schedule(self.current_epoch, 50, 0.996, 1)
        update_momentum(self.student_backbone, self.teacher_backbone, m=momentum)
        update_momentum(self.student_head, self.teacher_head, m=momentum)
        views, _, _ = batch
        views = [view.to(self.device) for view in views]
        global_views = views[:2]
        teacher_out = [self.forward_teacher(view) for view in global_views]
        student_out = [self.forward(view) for view in views]
        loss = self.criterion(teacher_out, student_out, epoch=self.current_epoch)
        if self.printed_epoch < self.current_epoch:
          self.printed_epoch+=1
          print(f"Training loss on Epoch {self.current_epoch}: {loss}")
          
        self.log("train_loss", loss, prog_bar=True, on_step=False, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        views, _, _ = batch
        views = [view.to(self.device) for view in views]
        global_views = views[:2]
        teacher_out = [self.forward_teacher(view) for view in global_views]
        student_out = [self.forward(view) for view in views]
        loss = self.criterion(teacher_out, student_out, epoch=self.current_epoch)
        self.log("val_loss", loss, prog_bar=True, on_step=False, on_epoch=True)
        if(self.current_epoch==19):
          print()
          print(f"Validation loss on Epoch {self.current_epoch}: {loss}")
          print()


    def on_after_backward(self):
        self.student_head.cancel_last_layer_gradients(current_epoch=self.current_epoch)

    def configure_optimizers(self):
        optim = torch.optim.Adam(self.parameters(), lr=self.lr)
        return optim
    @property
    def backbone(self):
      return self.student_backbone  # or self.teacher_backbone, depending on what you need

# %% [markdown]
# # *Create Augmentations*:
# When choosing the augmentations, you should keep in mind the characteristics of the problem. we are working with archaeology writing which could likely be affected by camera position, random cracks, "old photo" effects, random deletions (crops), and random lighting. Here are some suggestions on how you can handle these:
#
# 1. **Camera Position:** We can simulate the effect of changing camera position by transformations such as rotation and shearing. Torchvision provides transforms like `torchvision.transforms.RandomRotation` and `torchvision.transforms.RandomAffine` (which can handle shearing) **-We will use the first**.
#
# 2. **Random Cracks:** Simulating cracks could be a bit tricky. we might consider a custom transformation that randomly applies lines (cracks) on the image. Another option could be using `torchvision.transforms.RandomErasing` which randomly "erases" rectangular areas in the image **-We will not use it for now**.
#
# 3. **Old Photo Effect:** This usually involves changing the color balance of the image to give it a "faded" look, and possibly adding noise. We could use `torchvision.transforms.ColorJitter` to alter the color balance and `torchvision.transforms.Lambda` to apply a custom function that adds noise to the image **-We will use the first**.
#
# 4. **Random Deletes (Random Crops):** You can use `torchvision.transforms.RandomResizedCrop` which randomly crops the image and then resizes it back to the original size **-We will use it**.
#
# 5. **Random Lighting:** `torchvision.transforms.ColorJitter` can be used to simulate changes in brightness, which can mimic the effect of different lighting conditions **-We will use it**.
#
# Here's how I define these transformations using DINOtransform from lightly.ai:

# %%
import torch
from lightly.transforms.dino_transform import DINOTransform

# caculate std and mean for normalize for DINOtransform
def calculate_mean_std(dataset):
    loader = torch.utils.data.DataLoader(dataset, batch_size=1, shuffle=False)
    mean = torch.zeros(3)
    std = torch.zeros(3)
    nb_samples = 0.
    for data, _ in loader:  # assuming your dataset returns a tuple of (data, label)
        batch_samples = data.size(0)
        data = data.view(batch_samples, data.size(1), -1)
        mean += data.mean(2).sum(0)
        std += data.std(2).sum(0)
        nb_samples += batch_samples

    mean /= nb_samples
    std /= nb_samples
    return mean, std

custom_pytorch_dataset = CustomDataset(CSV_DATASET_PATH)
transform = DINOTransform()
dataset = LightlyDataset.from_torch_dataset(custom_pytorch_dataset, transform=transform)
mean, std = calculate_mean_std(custom_pytorch_dataset)
print(f'Mean: {mean}, Std: {std}')

transform= DINOTransform(
    global_crop_size=224, 
    global_crop_scale=(0.08, 1.0),  # ~RandomResizedCrop
    local_crop_size=96,  # Smaller crop for the local view
    local_crop_scale=(0.05, 0.4),  # Smaller scale for the local view
    n_local_views=6,  # 

    hf_prob=0,  # NO ~Horizontal Flip
    vf_prob=0,  # NO ~Vertical Flip for additional invariance
    
    rr_prob=0.5,  # ~Random Rotation
    rr_degrees=(0, 360),  # Rotate randomly between 0 and 360 degree
    
    cj_prob=0.8,  # ~Color Jitter
    cj_strength=0.5,  
    cj_bright=0.8,  # to simulate the changing light
    cj_contrast=0.8,  #to simulate old photo effect
    random_gray_scale=0.2,  # Convert to grayscale with a small probability
    gaussian_blur=(0.1, 0.5, 0.5),  # Apply gaussian blur with some probability
    sigmas=(0.1, 2.0),  # Adjust these values based on your dataset
    solarization_prob=0.2,  # Apply solarization with some probability
    normalize={'mean': mean, 'std': std}  # Normalization values for ImageNet, adjust if necessary
)
# Out:
# Mean: tensor([175.9199, 175.9199, 175.9199]), Std: tensor([70.3644, 70.3644, 70.3644])

# %% [markdown]
# #*TEST Overfit on a Single Batch*:

# %%
#TEST OVERFIT single Batch

import pytorch_lightning as pl
import torch
from lightly.data import LightlyDataset


def experiment_overfit_single_batch():
    print();print();print()
    print("~"*41)
    print("~"*5+"START TEST Single Batch overfit"+"~"*5)
    print("~"*41)
    try:
      
      dataloader = torch.utils.data.DataLoader(dataset, batch_size=32,  
                                          shuffle=False,num_workers=4  
                                          )
      trainer = pl.Trainer(overfit_batches=1, max_epochs=5, devices=1, accelerator=accelerator, log_every_n_steps=1)
      #import pdb; pdb.set_trace() #Debugger
      trainer.fit(model=model, train_dataloaders=dataloader)
      print("TEST Single Batch overfit: Success")
    except:
      print("TEST Single Batch overfit: FAIL")
    finally:
      print("~"*5+"END OF TEST"+"~"*5)
      print();print();print()




accelerator = "gpu" if torch.cuda.is_available() else "cpu"
print(accelerator)

custom_pytorch_dataset = CustomDataset(CSV_DATASET_PATH)
model = DINO()
dataset = LightlyDataset.from_torch_dataset(custom_pytorch_dataset, transform=transform)
experiment_overfit_single_batch()

# %% [markdown]
# # #*TEST Find Best Learning Rate Paramter:*

# %%
#Find Best Learning Rate paramter

import copy

import pytorch_lightning as pl
import torch
import torchvision
from lightly.data import LightlyDataset
from lightly.data.multi_view_collate import MultiViewCollate
from lightly.transforms.dino_transform import DINOTransform
from torch.utils.data import random_split
from pytorch_lightning.callbacks import ModelCheckpoint



accelerator = "gpu" if torch.cuda.is_available() else "cpu"
print(accelerator)
custom_pytorch_dataset = CustomDataset(CSV_DATASET_PATH)
model = DINO()
dataset = LightlyDataset.from_torch_dataset(custom_pytorch_dataset, transform=transform)


# Assuming dataset is full dataset
train_size = int(0.8 * len(dataset))  # Use 80% of the data for training
val_size = len(dataset) - train_size  # Use the rest for validation
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_dataloader = torch.utils.data.DataLoader(train_dataset,
                                            batch_size=16,
                                            shuffle=True,
                                            num_workers=4)
val_dataloader = torch.utils.data.DataLoader(val_dataset,
                                          batch_size=16,
                                          shuffle=False,
                                          num_workers=4)

checkpoint_callback = ModelCheckpoint(monitor='val_loss',
                                  save_top_k=1, 
                                  mode='min', 
                                  filename='dino_model-{epoch:02d}-{val_loss:.2f}')

# Define the learning rates to test
learning_rates = [0.1,0.05, 0.01, 0.005,0.001]

best_lr = None
best_val_loss = float('inf')
best_model = None

# Iterate over learning rates
for lr in learning_rates:
    # Instantiate the model with the current learning rate
    model = DINO(lr=lr)

    MAX_EPOCHS = 10
    trainer = pl.Trainer(max_epochs=MAX_EPOCHS, devices=1, accelerator=accelerator,callbacks=[checkpoint_callback])
    trainer.fit(model=model, train_dataloaders=train_dataloader, val_dataloaders=val_dataloader,)

    # After training, check if this model is the best so far
    if checkpoint_callback.best_model_score.item() < best_val_loss:
        best_val_loss = checkpoint_callback.best_model_score.item()
        best_lr = lr
        best_model = model

print(f"Best learning rate: {best_lr}")
# Save the best learning rate and validation loss to a CSV file
df = pd.DataFrame({"Learning Rate": [best_lr], "Validation Loss": [best_val_loss]})
df.to_csv("search_learning_rate_and_loss_results.csv", index=False)
# Save the best model's parameters to a .ckpt file
torch.save(best_model.state_dict(), "hyperparameter_lrsearch_best_model.ckpt")
# Out:
# gpu
# Using cache found in /root/.cache/torch/hub/facebookresearch_dino_main
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Using cache found in /root/.cache/torch/hub/facebookresearch_dino_main
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name             | Type               | Params
# --------------------------------------------------------
# 0 | student_backbone | VisionTransformer  | 21.7 M
# 1 | student_head     | DINOProjectionHead | 625 K
# 2 | teacher_backbone | VisionTransformer  | 21.7 M
# 3 | teacher_head     | DINOProjectionHead | 625 K
# 4 | criterion        | DINOLoss           | 0
# --------------------------------------------------------
# 22.3 M    Trainable params
# 22.3 M    Non-trainable params
# 44.6 M    Total params
# 178.331   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:280: PossibleUserWarning: The number of training batches (21) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Training loss on Epoch 0: 8.577797889709473
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 1: 8.173175811767578
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 2: 7.444267749786377
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 3: 7.5942888259887695
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 4: 7.5557942390441895
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 5: 7.609531402587891
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 6: 7.627763748168945
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 7: 7.623013496398926
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 8: 7.6240153312683105
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 9: 7.624473571777344
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# Using cache found in /root/.cache/torch/hub/facebookresearch_dino_main
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:612: UserWarning: Checkpoint directory /content/lightning_logs/version_1/checkpoints exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name             | Type               | Params
# --------------------------------------------------------
# 0 | student_backbone | VisionTransformer  | 21.7 M
# 1 | student_head     | DINOProjectionHead | 625 K
# 2 | teacher_backbone | VisionTransformer  | 21.7 M
# 3 | teacher_head     | DINOProjectionHead | 625 K
# 4 | criterion        | DINOLoss           | 0
# --------------------------------------------------------
# 22.3 M    Trainable params
# 22.3 M    Non-trainable params
# 44.6 M    Total params
# 178.331   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Training loss on Epoch 0: 8.365503311157227
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 1: 8.198525428771973
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 2: 7.637259483337402
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 3: 7.621010780334473
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 4: 7.610437393188477
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 5: 7.617520332336426
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 6: 7.621978282928467
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 7: 7.623224258422852
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 8: 7.623909950256348
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 9: 7.6242475509643555
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# Using cache found in /root/.cache/torch/hub/facebookresearch_dino_main
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name             | Type               | Params
# --------------------------------------------------------
# 0 | student_backbone | VisionTransformer  | 21.7 M
# 1 | student_head     | DINOProjectionHead | 625 K
# 2 | teacher_backbone | VisionTransformer  | 21.7 M
# 3 | teacher_head     | DINOProjectionHead | 625 K
# 4 | criterion        | DINOLoss           | 0
# --------------------------------------------------------
# 22.3 M    Trainable params
# 22.3 M    Non-trainable params
# 44.6 M    Total params
# 178.331   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Training loss on Epoch 0: 8.474806785583496
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 1: 8.271025657653809
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 2: 7.687288284301758
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 3: 7.589820384979248
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 4: 7.615357875823975
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 5: 7.620285511016846
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 6: 7.621952533721924
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 7: 7.622349262237549
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 8: 7.622856616973877
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 9: 7.623244285583496
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# Using cache found in /root/.cache/torch/hub/facebookresearch_dino_main
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name             | Type               | Params
# --------------------------------------------------------
# 0 | student_backbone | VisionTransformer  | 21.7 M
# 1 | student_head     | DINOProjectionHead | 625 K
# 2 | teacher_backbone | VisionTransformer  | 21.7 M
# 3 | teacher_head     | DINOProjectionHead | 625 K
# 4 | criterion        | DINOLoss           | 0
# --------------------------------------------------------
# 22.3 M    Trainable params
# 22.3 M    Non-trainable params
# 44.6 M    Total params
# 178.331   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Training loss on Epoch 0: 8.436200141906738
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 1: 8.183244705200195
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 2: 7.479280948638916
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 3: 7.702709674835205
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 4: 7.627035617828369
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 5: 7.620335102081299
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 6: 7.6206512451171875
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 7: 7.622179985046387
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 8: 7.623022556304932
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 9: 7.62351131439209
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# Using cache found in /root/.cache/torch/hub/facebookresearch_dino_main
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name             | Type               | Params
# --------------------------------------------------------
# 0 | student_backbone | VisionTransformer  | 21.7 M
# 1 | student_head     | DINOProjectionHead | 625 K
# 2 | teacher_backbone | VisionTransformer  | 21.7 M
# 3 | teacher_head     | DINOProjectionHead | 625 K
# 4 | criterion        | DINOLoss           | 0
# --------------------------------------------------------
# 22.3 M    Trainable params
# 22.3 M    Non-trainable params
# 44.6 M    Total params
# 178.331   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Training loss on Epoch 0: 8.331343650817871
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 1: 8.187490463256836
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 2: 7.618512153625488
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 3: 7.657634735107422
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 4: 7.626350402832031
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 5: 7.617222309112549
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 6: 7.6200056076049805
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 7: 7.620673656463623
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 8: 7.622284412384033
# Validation: 0it [00:00, ?it/s]
# Training loss on Epoch 9: 7.622958660125732
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.
# Best learning rate: 0.1

# %% [markdown]
# # *Start Real Training:*

# %%
# Real Training

import copy
import pytorch_lightning as pl
import torch
import torchvision
from lightly.data import LightlyDataset
from lightly.data.multi_view_collate import MultiViewCollate
from lightly.transforms.dino_transform import DINOTransform
from torch.utils.data import random_split
from pytorch_lightning.callbacks import ModelCheckpoint

if __name__ == '__main__':
    accelerator = "gpu" if torch.cuda.is_available() else "cpu"
    print(accelerator)
    custom_pytorch_dataset = CustomDataset(CSV_DATASET_PATH)
    dataset = LightlyDataset.from_torch_dataset(custom_pytorch_dataset, transform=transform)
    train_size = int(0.8 * len(dataset))  # Use 80% of the data for training
    val_size = len(dataset) - train_size  # Use the rest for validation
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
    train_dataloader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=32,
                                               shuffle=True,
                                               num_workers=4)
    val_dataloader = torch.utils.data.DataLoader(val_dataset,
                                             batch_size=32,
                                             shuffle=False,
                                             num_workers=4)

    MAX_EPOCHS = 180
    checkpoint_callback = ModelCheckpoint(monitor='val_loss',
                                      save_top_k=1, 
                                      mode='min', 
                                      filename='dino_model-{epoch:02d}-{val_loss:.2f}')
    try:
        training_lr = best_lr
    except:
        training_lr = 0.001

    
    best_model = DINO(training_lr) # IF Lr cant be found(not run above cell) need to hard incode to save it
    trainer = pl.Trainer(max_epochs=MAX_EPOCHS, accelerator=accelerator,callbacks=[checkpoint_callback])
    trainer.fit(model=best_model, train_dataloaders=train_dataloader, val_dataloaders=val_dataloader,)

    trainer.save_checkpoint("final_dino_model.ckpt") # remmber to donwload it locally it will be deleted in colab !

# %% [markdown]
# # Download Weights With ZIP After Training

# %%
# Download Weights With ZIP
# !zip -r /content/final_dino_model.zip /content/final_dino_model.ckpt
from google.colab import files
files.download("/content/final_dino_model.zip")
# Out:
# updating: content/final_dino_model.ckpt (deflated 8%)

# %% [markdown]
# # Load Model Weights Extract From Zip and intilaize Model#
# ### Drag and drop ziped model weights file named final_dino_model.zip in path "/content/HERE" (located in https://drive.google.com/drive/folders/1RZWxjr8cXaWmjOspGbIPFmN1TVrVSIYX?usp=sharing_eip_m&ts=642c12f4)###

# %%
#LOAD Model Weights
from zipfile import ZipFile
file_name = "/content/final_dino_model.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')


best_model = DINO.load_from_checkpoint('/content/final_dino_model.ckpt')
# make sure to call .eval() when doing inference
best_model.eval()
# Out:
# Done
# Using cache found in /root/.cache/torch/hub/facebookresearch_dino_main
# DINO(
#   (student_backbone): VisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (pos_drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0-11): 12 x Block(
#         (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=384, out_features=1152, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=384, out_features=384, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=384, out_features=1536, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1536, out_features=384, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#     (head): Identity()
#   )
#   (student_head): DINOProjectionHead(
#     (layers): Sequential(
#       (0): Linear(in_features=384, out_features=512, bias=True)
#       (1): GELU(approximate='none')
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): GELU(approximate='none')
#       (4): Linear(in_features=512, out_features=64, bias=True)
#     )
#     (last_layer): Linear(in_features=64, out_features=2048, bias=False)
#   )
#   (teacher_backbone): VisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (pos_drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0-11): 12 x Block(
#         (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=384, out_features=1152, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=384, out_features=384, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=384, out_features=1536, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1536, out_features=384, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#     (head): Identity()
#   )
#   (teacher_head): DINOProjectionHead(
#     (layers): Sequential(
#       (0): Linear(in_features=384, out_features=512, bias=True)
#       (1): GELU(approximate='none')
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): GELU(approximate='none')
#       (4): Linear(in_features=512, out_features=64, bias=True)
#     )
#     (last_layer): Linear(in_features=64, out_features=2048, bias=False)
#   )
#   (criterion): DINOLoss()
# )

# %% [markdown]
# # *Run KNN on embeddings to check current results:*
# ##Create Enbeddings:##

# %%
# TEST NEW generate_embeddings Code:
import torchvision.transforms as transforms
# from sklearn.preprocessing import normalize


def generate_embeddings(model, dataset):
    """Generates representations for all images in the dataloader with
    the given model. When embeddings is sahped (N_samples,D_features)
    """
    train_dataloader = torch.utils.data.DataLoader(train_dataset,
                                            batch_size=1,
                                            shuffle=True,
                                            num_workers=2)
    embeddings = []
    filenames = []
    grayscale_transform = transforms.Grayscale()

    with torch.no_grad():
        for img, label, fnames in train_dataloader:
            #img = grayscale_transform(img)  # convert to grayscale
            img = img.to(model.device)
            # make sure the images are on the same device as the model
            img = torch.squeeze(img,0)  # remove the second dimension
            #img = grayscale_transform(img)
            print("samples shape: ",img.shape)
            # generate the embedding and flatten to 1D
            emb = model.backbone(img).flatten(start_dim=1)
            print("emb shape: ",emb.shape)
            embeddings.append(emb)
            b =  torch.stack(embeddings, dim=0)
            b=torch.squeeze(b,1)
            print("Cureent embeding shape: ",b.shape)
            print()
            # collect the filenames
            filenames.extend(list(label["sample_path"]))

    # stack all embeddings into a 2D tensor
    embeddings = torch.stack(embeddings, dim=0)
    embeddings = torch.squeeze(embeddings,1)
    print("~~~Last embeding shape: ",embeddings.shape)

    # normalize the embeddings to have unit length
    # embeddings = normalize(embeddings.cpu())

    return embeddings, filenames

# #Load Dataset
custom_pytorch_dataset = CustomDataset(CSV_DATASET_PATH)
dataset = LightlyDataset.from_torch_dataset(custom_pytorch_dataset, transform=transform)
train_size = int(0.8 * len(dataset))  # Use 80% of the data for training
val_size = len(dataset) - train_size  # Use the rest for validation
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_dataloader = torch.utils.data.DataLoader(train_dataset,
                                            batch_size=32,
                                            shuffle=True,
                                            num_workers=4)
val_dataloader = torch.utils.data.DataLoader(val_dataset,
                                          batch_size=32,
                                          shuffle=False,
                                          num_workers=4)
embeddings, filenames = generate_embeddings(best_model, train_dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([1, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([2, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([3, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([4, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([5, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([6, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([7, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([8, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([9, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([10, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([11, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([12, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([13, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([14, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([15, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([16, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([17, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([18, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([19, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([20, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([21, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([22, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([23, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([24, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([25, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([26, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([27, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([28, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([29, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([30, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([31, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([32, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([33, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([34, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([35, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([36, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([37, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([38, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([39, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([40, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([41, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([42, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([43, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([44, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([45, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([46, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([47, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([48, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([49, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([50, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([51, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([52, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([53, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([54, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([55, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([56, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([57, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([58, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([59, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([60, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([61, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([62, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([63, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([64, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([65, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([66, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([67, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([68, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([69, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([70, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([71, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([72, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([73, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([74, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([75, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([76, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([77, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([78, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([79, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([80, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([81, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([82, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([83, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([84, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([85, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([86, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([87, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([88, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([89, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([90, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([91, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([92, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([93, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([94, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([95, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([96, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([97, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([98, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([99, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([100, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([101, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([102, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([103, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([104, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([105, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([106, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([107, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([108, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([109, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([110, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([111, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([112, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([113, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([114, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([115, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([116, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([117, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([118, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([119, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([120, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([121, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([122, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([123, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([124, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([125, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([126, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([127, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([128, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([129, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([130, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([131, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([132, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([133, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([134, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([135, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([136, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([137, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([138, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([139, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([140, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([141, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([142, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([143, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([144, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([145, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([146, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([147, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([148, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([149, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([150, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([151, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([152, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([153, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([154, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([155, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([156, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([157, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([158, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([159, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([160, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([161, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([162, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([163, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([164, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([165, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([166, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([167, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([168, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([169, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([170, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([171, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([172, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([173, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([174, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([175, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([176, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([177, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([178, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([179, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([180, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([181, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([182, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([183, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([184, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([185, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([186, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([187, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([188, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([189, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([190, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([191, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([192, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([193, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([194, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([195, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([196, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([197, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([198, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([199, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([200, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([201, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([202, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([203, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([204, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([205, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([206, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([207, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([208, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([209, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([210, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([211, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([212, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([213, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([214, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([215, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([216, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([217, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([218, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([219, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([220, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([221, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([222, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([223, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([224, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([225, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([226, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([227, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([228, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([229, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([230, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([231, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([232, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([233, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([234, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([235, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([236, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([237, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([238, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([239, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([240, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([241, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([242, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([243, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([244, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([245, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([246, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([247, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([248, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([249, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([250, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([251, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([252, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([253, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([254, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([255, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([256, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([257, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([258, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([259, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([260, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([261, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([262, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([263, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([264, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([265, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([266, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([267, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([268, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([269, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([270, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([271, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([272, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([273, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([274, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([275, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([276, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([277, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([278, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([279, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([280, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([281, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([282, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([283, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([284, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([285, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([286, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([287, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([288, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([289, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([290, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([291, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([292, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([293, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([294, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([295, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([296, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([297, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([298, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([299, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([300, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([301, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([302, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([303, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([304, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([305, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([306, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([307, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([308, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([309, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([310, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([311, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([312, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([313, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([314, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([315, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([316, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([317, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([318, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([319, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([320, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([321, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([322, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([323, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([324, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([325, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([326, 384])
#
# ~~~Last embeding shape:  torch.Size([326, 384])

# %% [markdown]
# ##*Plot with KNN Closest Neighbors of random Embeding vectors*##

# %%
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt
from PIL import Image
import os
import numpy as np
import torch
def get_image_as_np_array(filename: str):
    """Returns an image as an numpy array"""
    img = Image.open(filename)
    return np.asarray(img)


def plot_knn_examples(embeddings, filenames, n_neighbors=5, num_examples=6):
    """Plots multiple rows of random images with their nearest neighbors"""
    # lets look at the nearest neighbors for some samples
    # we use the sklearn library
    nbrs = NearestNeighbors(n_neighbors=n_neighbors).fit(embeddings)
    distances, indices = nbrs.kneighbors(embeddings)
    print(f"First Five of:\ndistances: {distances[:5]}\nindices: {indices[:5]}")
    print()
    print("Graph of Nearest Neighbors by distances multiply by 10 to the power of 7 because of normalization")
    # get 5 random samples
    samples_idx = np.random.choice(len(indices), size=num_examples, replace=False)
    plot_width = 6

    # Define the width and height of each plot
    plot_width = 6
    plot_height = 4

    for idx in samples_idx:
        fig = plt.figure(figsize=(plot_width * len(indices[idx]), plot_height))
        # loop through their nearest neighbors
        for plot_x_offset, neighbor_idx in enumerate(indices[idx]):
            # add the subplot
            ax = fig.add_subplot(1, len(indices[idx]), plot_x_offset + 1)
            # get the corresponding filename for the current index
            fname = os.path.join(filenames[neighbor_idx])
            # plot the image
            plt.imshow(get_image_as_np_array(fname))
            # set the title to the distance of the neighbor
            ax.set_title(f"d*10**7={distances[idx][plot_x_offset]*(10**7):.3f}")
            # let's disable the axis
            plt.axis("off")
plot_knn_examples(embeddings, filenames)
# Out:
# First Five of:
# distances: [[2.69739830e-06 7.19434611e-04 1.28628854e-03 1.34732278e-03
#   1.38780291e-03]
#  [3.81469727e-06 7.02010541e-04 1.63376519e-03 1.77548342e-03
#   2.72443305e-03]
#  [3.81469727e-06 6.22682875e-04 8.79259792e-04 1.15380720e-03
#   1.33020988e-03]
#  [3.81469727e-06 1.45068754e-03 2.75305674e-03 4.47085571e-03
#   4.53381805e-03]
#  [3.30362474e-06 3.60423289e-04 4.26901099e-04 5.60719949e-04
#   8.68893083e-04]]
# indices: [[  0 283 124 110  49]
#  [  1 155 142  60 318]
#  [  2  35 305  16 286]
#  [  3 210 205  19 194]
#  [  4 244 151 255 195]]
#
# Graph of Nearest Neighbors by distances multiply by 10 to the power of 7 because of normalization

# %% [markdown]
# #Classifier From K-means from *Embedding* **bold text**#

# %%
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt
from PIL import Image
import os
import numpy as np
import torch
class DinoKMeansClassifier:
    def __init__(self, model, n_clusters=22):
        self.model = model
        self.kmeans = KMeans(n_clusters=n_clusters)
        self.embeddings = None
        self.filenames = None

    def fit(self, dataset):
     
        if self.embeddings == None:
            self.embeddings, self.filenames=self.create_kmeans_train_data(dataset)
    
        self.kmeans.fit(self.embeddings)

    def generate_neighbors(self, dataset):
        print("Create Embedding Starts:")
        train_dataloader = torch.utils.data.DataLoader(train_dataset,
                                                batch_size=1,
                                                shuffle=True,
                                                num_workers=2)
        embeddings = []
        filenames = []
        #import pdb; pdb.set_trace() #Debugger

        with torch.no_grad():
            for img, label, fnames in train_dataloader:
                img = img.to(self.model.device)
                img = torch.squeeze(img,0)  # remove the second dimension
                print("samples shape: ",img.shape)
                emb = self.model.backbone(img).flatten(start_dim=1)
                print("emb shape: ",emb.shape)
                embeddings.append(emb)
                b =  torch.stack(embeddings, dim=0)
                b=torch.squeeze(b,1)
                print("Cureent embeding shape: ",b.shape)
                print()
                filenames.extend(list(label["sample_path"]))

        # stack all embeddings into a 2D tensor
        embeddings = torch.stack(embeddings, dim=0)
        embeddings = torch.squeeze(embeddings,1)
        print("~~~Last BEFORE embeding shape: ",embeddings.shape)

        embeddings = embeddings.view(embeddings.size(0), -1).detach().cpu().numpy()

        print("~~~Last AFTER embeding shape: ",embeddings.shape)
        return embeddings, filenames


    def create_kmeans_train_data(self, dataset):
      return self.generate_neighbors(dataset)

    def classify(self, img):
        if not isinstance(img, np.ndarray):
          img = img.to(self.model.device)
       #img = torch.squeeze(img,0)  # remove the second dimension
        print("img shape in classify: ",img.shape)
        emb = self.model.backbone(img).flatten(start_dim=1)
        return self.kmeans.predict(emb)

    def plot_cluster_images(self, img, n_images=2):
      # Classify the input image
      cluster = self.classify(img)
      
      # Get indices of embeddings in the same cluster
      cluster_indices = np.where(self.kmeans.labels_ == cluster)[0]
      
      # Randomly select n_images - 1 images from the cluster
      random_indices = np.random.choice(cluster_indices, size=n_images-1, replace=False)
      
      # Plot the original image
      fig = plt.figure()
      ax = fig.add_subplot(1, n_images, 1)
      plt.imshow(img.permute(1, 2, 0).numpy())
      plt.axis("off")
      ax.set_title("Original Image")
      
      # Plot the images from the same cluster
      for i, index in enumerate(random_indices):
          ax = fig.add_subplot(1, n_images, i + 2)
          fname = os.path.join(self.filenames[index])
          plt.imshow(Image.open(fname))
          plt.axis("off")
          ax.set_title("Cluster Image")
      
      plt.show()

# #Load Dataset
custom_pytorch_dataset = CustomDataset(CSV_DATASET_PATH)
dataset = LightlyDataset.from_torch_dataset(custom_pytorch_dataset, transform=transform)
train_size = int(0.8 * len(dataset))  # Use 80% of the data for training
val_size = len(dataset) - train_size  # Use the rest for validation
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_dataloader = torch.utils.data.DataLoader(train_dataset,
                                            batch_size=32,
                                            shuffle=True,
                                            num_workers=4)
val_dataloader = torch.utils.data.DataLoader(val_dataset,
                                          batch_size=32,
                                          shuffle=False,
                                          num_workers=4)
print(train_dataset)
# instantiate the classifier and fit it using the training data
classifier = DinoKMeansClassifier(best_model, n_clusters=22)
classifier.fit(train_dataset)
# Out:
# <torch.utils.data.dataset.Subset object at 0x7fbbef4fa290>
# Create Embedding Starts:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([1, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([2, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([3, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([4, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([5, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([6, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([7, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([8, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([9, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([10, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([11, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([12, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([13, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([14, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([15, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([16, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([17, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([18, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([19, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([20, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([21, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([22, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([23, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([24, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([25, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([26, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([27, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([28, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([29, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([30, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([31, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([32, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([33, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([34, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([35, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([36, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([37, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([38, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([39, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([40, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([41, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([42, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([43, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([44, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([45, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([46, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([47, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([48, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([49, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([50, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([51, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([52, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([53, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([54, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([55, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([56, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([57, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([58, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([59, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([60, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([61, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([62, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([63, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([64, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([65, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([66, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([67, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([68, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([69, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([70, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([71, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([72, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([73, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([74, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([75, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([76, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([77, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([78, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([79, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([80, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([81, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([82, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([83, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([84, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([85, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([86, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([87, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([88, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([89, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([90, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([91, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([92, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([93, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([94, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([95, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([96, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([97, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([98, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([99, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([100, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([101, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([102, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([103, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([104, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([105, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([106, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([107, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([108, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([109, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([110, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([111, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([112, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([113, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([114, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([115, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([116, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([117, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([118, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([119, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([120, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([121, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([122, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([123, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([124, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([125, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([126, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([127, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([128, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([129, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([130, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([131, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([132, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([133, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([134, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([135, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([136, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([137, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([138, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([139, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([140, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([141, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([142, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([143, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([144, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([145, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([146, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([147, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([148, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([149, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([150, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([151, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([152, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([153, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([154, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([155, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([156, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([157, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([158, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([159, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([160, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([161, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([162, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([163, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([164, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([165, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([166, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([167, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([168, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([169, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([170, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([171, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([172, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([173, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([174, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([175, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([176, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([177, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([178, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([179, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([180, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([181, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([182, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([183, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([184, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([185, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([186, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([187, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([188, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([189, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([190, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([191, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([192, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([193, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([194, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([195, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([196, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([197, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([198, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([199, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([200, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([201, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([202, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([203, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([204, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([205, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([206, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([207, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([208, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([209, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([210, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([211, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([212, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([213, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([214, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([215, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([216, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([217, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([218, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([219, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([220, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([221, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([222, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([223, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([224, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([225, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([226, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([227, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([228, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([229, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([230, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([231, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([232, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([233, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([234, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([235, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([236, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([237, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([238, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([239, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([240, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([241, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([242, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([243, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([244, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([245, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([246, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([247, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([248, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([249, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([250, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([251, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([252, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([253, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([254, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([255, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([256, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([257, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([258, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([259, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([260, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([261, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([262, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([263, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([264, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([265, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([266, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([267, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([268, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([269, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([270, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([271, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([272, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([273, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([274, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([275, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([276, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([277, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([278, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([279, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([280, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([281, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([282, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([283, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([284, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([285, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([286, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([287, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([288, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([289, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([290, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([291, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([292, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([293, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([294, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([295, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([296, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([297, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([298, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([299, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([300, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([301, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([302, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([303, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([304, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([305, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([306, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([307, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([308, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([309, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([310, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([311, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([312, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([313, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([314, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([315, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([316, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([317, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([318, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([319, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([320, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([321, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([322, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([323, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([324, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([325, 384])
#
# samples shape:  torch.Size([1, 3, 384, 384])
# emb shape:  torch.Size([1, 384])
# Cureent embeding shape:  torch.Size([326, 384])
#
# ~~~Last BEFORE embeding shape:  torch.Size([326, 384])
# ~~~Last AFTER embeding shape:  (326, 384)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Get the first batch from the validation data loader
batch = next(iter(val_dataloader))

# Extract the images from the batch
images = batch[0][:5]

# Plot the cluster images for each image
for img in images:
    # Plot cluster images
    print("img shape: ", img.shape)
    classifier.plot_cluster_images(img, n_images=2)
